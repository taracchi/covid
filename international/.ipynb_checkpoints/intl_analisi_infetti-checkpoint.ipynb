# %%
import matplotlib.pyplot as plt
import seaborn as sns
from aidam.math_utils import moving_function_rev1
from aidam.aicharts import get_subplot_cells_sequence, confplot_ax, auto_grid_shape
import pickle as pkl
import numpy as np
import pandas as pd

# %% [markdown]
# ## Lettura dati

# %%
data_file='international_data.pkl'

infile=open(data_file,'rb')
trend=pkl.load(infile)
nazioni=pkl.load(infile)
continent_nations=pkl.load(infile)
infile.close()

# %%
for naz in nazioni:
    print('%30s DA: %s  A:  %s  [Samples: %3d]'%(naz,
                                                   trend['date'][naz][0],
                                                   trend['date'][naz][-1],
                                                  len(np.unique(trend['date'][naz]))))
# Out:
#                    Afghanistan DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                        Albania DA: 2020-03-09  A:  2020-09-10  [Samples: 186]
#                        Algeria DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                        Andorra DA: 2020-03-03  A:  2020-09-10  [Samples: 187]
#                         Angola DA: 2020-03-22  A:  2020-09-10  [Samples: 173]
#                       Anguilla DA: 2020-03-27  A:  2020-09-10  [Samples: 168]
#            Antigua and Barbuda DA: 2020-03-15  A:  2020-09-10  [Samples: 175]
#                      Argentina DA: 2020-02-11  A:  2020-09-10  [Samples: 213]
#                        Armenia DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                          Aruba DA: 2020-03-13  A:  2020-09-10  [Samples: 177]
#                      Australia DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                        Austria DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                     Azerbaijan DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                        Bahamas DA: 2020-03-16  A:  2020-09-10  [Samples: 177]
#                        Bahrain DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                     Bangladesh DA: 2020-03-04  A:  2020-09-10  [Samples: 191]
#                       Barbados DA: 2020-03-18  A:  2020-09-10  [Samples: 177]
#                        Belarus DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                        Belgium DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                         Belize DA: 2020-03-24  A:  2020-09-10  [Samples: 171]
#                          Benin DA: 2020-03-17  A:  2020-09-10  [Samples: 178]
#                        Bermuda DA: 2020-03-20  A:  2020-09-10  [Samples: 175]
#                         Bhutan DA: 2020-03-06  A:  2020-09-10  [Samples: 184]
#                        Bolivia DA: 2020-03-12  A:  2020-09-10  [Samples: 183]
# Bonaire Sint Eustatius and Saba DA: 2020-04-02  A:  2020-09-10  [Samples: 162]
#         Bosnia and Herzegovina DA: 2020-03-06  A:  2020-09-10  [Samples: 184]
#                       Botswana DA: 2020-04-01  A:  2020-09-10  [Samples: 163]
#                         Brazil DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#         British Virgin Islands DA: 2020-03-27  A:  2020-09-10  [Samples: 168]
#                         Brunei DA: 2020-03-10  A:  2020-09-10  [Samples: 184]
#                       Bulgaria DA: 2020-03-08  A:  2020-09-10  [Samples: 185]
#                   Burkina Faso DA: 2020-03-11  A:  2020-09-10  [Samples: 182]
#                        Burundi DA: 2020-04-01  A:  2020-09-10  [Samples: 163]
#                       Cambodia DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                       Cameroon DA: 2020-03-07  A:  2020-09-10  [Samples: 184]
#                         Canada DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                     Cape Verde DA: 2020-03-21  A:  2020-09-10  [Samples: 174]
#                 Cayman Islands DA: 2020-03-20  A:  2020-09-10  [Samples: 175]
#       Central African Republic DA: 2020-03-16  A:  2020-09-10  [Samples: 179]
#                           Chad DA: 2020-03-20  A:  2020-09-10  [Samples: 175]
#                          Chile DA: 2020-03-04  A:  2020-09-10  [Samples: 190]
#                          China DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#
A: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                 Western Sahara DA: 2020-04-26  A:  2020-09-10  [Samples: 138]
#                          Yemen DA: 2020-04-10  A:  2020-09-10  [Samples: 154]
#                         Zambia DA: 2020-03-19  A:  2020-09-10  [Samples: 176]
#                       Zimbabwe DA: 2020-03-21  A:  2020-09-10  [Samples: 174]
#                          World DA: 2019-12-31  A:  2020-09-10  [Samples: 255]
#                  International DA: 2019-12-31  A:  2020-09-10  [Samples: 255]

# %% [markdown]
# ## Plot dati continentali

# %%
continente='europe'
num_nazioni=len(continent_nations[continente])

# %%
# per i subplot determina la griglia
grid_shape=auto_grid_shape(num_nazioni,cols=3)
grid_seq=get_subplot_cells_sequence(grid_shape)

# dimensioni figure (figsize) per figure singole e figure composte (subplot)
figsize_single=(9,6)
figsize_multi=(16,48)

# %%
#indicatori_selected=['new_cases','total_deaths', 'new_deaths', 'total_cases_per_million',
#       'new_cases_per_million', 'total_deaths_per_million','new_deaths_per_million']

#indicatori_selected=['new_cases_per_million','new_deaths_per_million']
indicatori_selected=['total_cases_per_million','total_deaths_per_million']

# %%
for indicatore in indicatori_selected:

    fig,ax=plt.subplots(grid_shape[0],grid_shape[1],sharey=False,figsize=figsize_multi)
    fig.suptitle(indicatore, y=1.02,fontsize=25)
    fig.tight_layout(pad=2.0)

    for i,naz in enumerate(continent_nations[continente]):
        #ax[grid_seq[i]].plot(range(len(trend['date'][naz])),trend[indicatore][naz],
        #                     'b-',linewidth=0.5,label='Reg')
        ax[grid_seq[i]].plot(range(len(trend['date'][naz])),moving_function_rev1(trend[indicatore][naz],np.mean,3,3),
                             'b-',linewidth=2,label='Trend')
        ax[grid_seq[i]].set_title(naz+' %s: %.1f'%(trend['date'][naz][-1],trend[indicatore][naz][-1]))
        #ax[grid_seq[i]].legend()
        ax[grid_seq[i]].grid()
        #ax[grid_seq[i]].set_yscale('log')
        
    fig.savefig('PIC_%s_%s.JPG'%(continente,indicatore))

# %%
for indicatore in indicatori_selected:
    valori=[trend[indicatore][naz][-1] for naz in continent_nations[continente]]
    plt.figure(figsize=(16,4))
    plt.title(indicatore)
    plt.bar(range(len(valori)),valori)
    plt.xticks(range(len(valori)),continent_nations[continente],rotation=90)
    plt.grid()
    plt.show()

# %% [markdown]
# #### Versione ordinata

# %%
for indicatore in indicatori_selected:
    valori=[trend[indicatore][naz][-1] for naz in continent_nations[continente]]
    ordine=np.argsort(valori)
    plt.figure(figsize=(16,4))
    plt.title(indicatore)
    plt.bar(range(len(valori)),valori[ordine])
    plt.xticks(range(len(valori)),continent_nations[continente][ordine],rotation=90)
    plt.grid()
    plt.show()

# %%
np.argsort(valori)
# Out:
# array([50, 16, 12, 43, 26,  8, 33, 27, 17, 20, 28, 31,  9, 11, 36,  7, 37,
#        13, 44, 19, 48,  3,  2,  6, 42, 10, 15,  0, 40, 38, 34, 18, 29, 47,
#         5, 39, 32, 22, 25, 30, 24, 21, 35, 14, 46, 23, 49, 45,  1,  4, 41],
#       dtype=int64)
