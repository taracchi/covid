# %% [markdown]
# # Analisi sulla consegne dei vaccini

# %%
import pandas as pd
import numpy as np
from datetime import datetime

import matplotlib.pyplot as plt

import seaborn as sns

from aidam.math_utils import moving_function_rev1

from aidam.miscellanea_utils import find_matlabstyle

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Parametri

# %%
data_file='https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/consegne-vaccini-latest.csv'

# %% [markdown]
# ## Lettura dati e preprocessing

# %%
consegne_data=pd.read_csv(data_file)
print(consegne_data.columns)

# riordino in base alla data (che creo e faccio indice)
consegne_data['data'] = pd.to_datetime(consegne_data['data_consegna'])
consegne_data.index=consegne_data['data']
consegne_data=consegne_data.sort_index()

# creo una colonna col numero di giorni dalla prima consegna
zero_day=consegne_data['data'][0]
day_counter=[(dd-zero_day).days for dd in consegne_data['data']]
consegne_data['day_counter']=day_counter

giorni=pd.unique(consegne_data['data_consegna'])

print('Giorni osservati: %d'%len(giorni))
print('Da: %s'%giorni[0][0:10])
print(' A: %s'%giorni[-1][0:10])
regioni=pd.unique(consegne_data['area'])

#data[data['denominazione_regione']=='Lombardia'].head(5)
consegne_data[consegne_data['area']=='TOS']#.tail(15)
# Out:
# Index(['area', 'fornitore', 'numero_dosi', 'data_consegna', 'codice_NUTS1',
#        'codice_NUTS2', 'codice_regione_ISTAT', 'nome_area'],
#       dtype='object')
# Giorni osservati: 45
# Da: 2020-12-27
#  A: 2021-03-04
#            area        fornitore  numero_dosi data_consegna codice_NUTS1  \
# data
# 2020-12-27  TOS  Pfizer/BioNTech          620    2020-12-27          ITI
# 2020-12-30  TOS  Pfizer/BioNTech        14625    2020-12-30          ITI
# 2020-12-31  TOS  Pfizer/BioNTech        12675    2020-12-31          ITI
# 2021-01-05  TOS  Pfizer/BioNTech         3900    2021-01-05          ITI
# 2021-01-07  TOS  Pfizer/BioNTech        20475    2021-01-07          ITI
# 2021-01-12  TOS  Pfizer/BioNTech        28275    2021-01-12          ITI
# 2021-01-13  TOS          Moderna         5300    2021-01-13          ITI
# 2021-01-18  TOS  Pfizer/BioNTech         4680    2021-01-18          ITI
# 2021-01-20  TOS  Pfizer/BioNTech         7020    2021-01-20          ITI
# 2021-01-21  TOS  Pfizer/BioNTech         7020    2021-01-21          ITI
# 2021-01-26  TOS  Pfizer/BioNTech        23400    2021-01-26          ITI
# 2021-01-27  TOS  Pfizer/BioNTech         5850    2021-01-27          ITI
# 2021-02-01  TOS          Moderna         4100    2021-02-01          ITI
# 2021-02-02  TOS  Pfizer/BioNTech        31590    2021-02-02          ITI
# 2021-02-09  TOS      AstraZeneca        15400    2021-02-09          ITI
# 2021-02-09  TOS  Pfizer/BioNTech        31590    2021-02-09          ITI
# 2021-02-13  TOS          Moderna         9600    2021-02-13          ITI
# 2021-02-13  TOS      AstraZeneca        18100    2021-02-13          ITI
# 2021-02-16  TOS  Pfizer/BioNTech         8190    2021-02-16          ITI
# 2021-02-18  TOS  Pfizer/BioNTech        36270    2021-02-18          ITI
# 2021-02-19  TOS      AstraZeneca        31300    2021-02-19          ITI
# 2021-02-23  TOS  Pfizer/BioNTech        44460    2021-02-23          ITI
# 2021-02-27  TOS      AstraZeneca        29900    2021-02-27          ITI
# 2021-03-01  TOS          Moderna        17700    2021-03-01          ITI
# 2021-03-02  TOS  Pfizer/BioNTech        46800    2021-03-02          ITI
#
#            codice_NUTS2  codice_regione_ISTAT nome_area       data  \
# data
# 2020-12-27         ITI1                     9   Toscana 2020-12-27
# 2020-12-30         ITI1                     9   Toscana 2020-12-30
# 2020-12-31         ITI1                     9   Toscana 2020-12-31
# 2021-01-05         ITI1                     9   Toscana 2021-01-05
# 2021-01-07         ITI1                     9   Toscana 2021-01-07
# 2021-01-12         ITI1                     9   Toscana 2021-01-12
# 2021-01-13         ITI1                     9   Toscana 2021-01-13
# 2021-01-18         ITI1                     9   Toscana 2021-01-18
# 2021-01-20         ITI1                     9   Toscana 2021-01-20
# 2021-01-21         ITI1                     9   Toscana 2021-01-21
# 2021-01-26         ITI1                     9   Toscana 2021-01-26
# 2021-01-27         ITI1                     9   Toscana 2021-01-27
# 2021-02-01         ITI1                     9   Toscana 2021-02-01
# 2021-02-02         ITI1                     9   Toscana 2021-02-02
# 2021-02-09         ITI1                     9   Toscana 2021-02-09
# 2021-02-09         ITI1                     9   Toscana 2021-02-09
# 2021-02-13         ITI1                     9   Toscana 2021-02-13
# 2021-02-13         ITI1                     9   Toscana 2021-02-13
# 2021-02-16         ITI1                     9   Toscana 2021-02-16
# 2021-02-18         ITI1                     9   Toscana 2021-02-18
# 2021-02-19         ITI1                     9   Toscana 2021-02-19
# 2021-02-23         ITI1                     9   Toscana 2021-02-23
# 2021-02-27         ITI1                     9   Toscana 2021-02-27
# 2021-03-01         ITI1                     9   Toscana 2021-03-01
# 2021-03-02         ITI1                     9   Toscana 2021-03-02
#
#             day_counter
# data
# 2020-12-27            0
# 2020-12-30            3
# 2020-12-31            4
# 2021-01-05            9
# 2021-01-07           11
# 2021-01-12           16
# 2021-01-13           17
# 2021-01-18           22
# 2021-01-20           24
# 2021-01-21           25
# 2021-01-26           30
# 2021-01-27           31
# 2021-02-01           36
# 2021-02-02           37
# 2021-02-09           44
# 2021-02-09           44
# 2021-02-13           48
# 2021-02-13           48
# 2021-02-16           51
# 2021-02-18           53
# 2021-02-19           54
# 2021-02-23           58
# 2021-02-27           62
# 2021-03-01           64
# 2021-03-02           65

# %%
consegne_ita=consegne_data.groupby(['data_consegna','fornitore']).sum()
consegne_ita.columns
# Out:
# Index(['numero_dosi', 'codice_regione_ISTAT', 'day_counter'], dtype='object')

# %% [markdown]
# ## Creazione struttura dati

# %%
# indicatori osservati
indicatori=['fornitore', 'numero_dosi', 'data_consegna','day_counter']

# qui immetto tutti i trend per ciascuna regione
consegne={}
for regione in regioni:
    consegne[regione]={}
    for ind in indicatori:    
        consegne[regione][ind]=np.array(consegne_data[consegne_data['area']==regione][ind])

# %%
consegne['TOS']

indici_tos_az=np.array(find_matlabstyle(consegne['TOS']['fornitore'],lambda x:x=='AstraZeneca'))
indici_tos_az
consegne['TOS']['data_consegna'][indici_tos_az]
# Out:
# array(['2021-02-09', '2021-02-13', '2021-02-19', '2021-02-27'],
#       dtype=object)

# %%
print(d0)
print(dd)
(dd-d0).days
# Out:
# 2020-12-27 00:00:00
# 2021-01-18 00:00:00
# 22

# %%
## Totale dosi per regione
