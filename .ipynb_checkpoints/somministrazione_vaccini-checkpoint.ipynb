# %% [markdown]
# # Somministrazione vaccini

# %%
import pandas as pd
import numpy as np
import datetime
import pickle as pkl

import matplotlib.pyplot as plt
import seaborn as sns
from aidam.math_utils import moving_function_rev1
#from aidam.miscellanea_utils import find_matlabstyle
#from aidam.aicharts import get_subplot_cells_sequence, confplot_ax, auto_grid_shape

import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Parametri

# %%
data_file='https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-summary-latest.csv'

# %% [markdown]
# ## Lettura dati e preprocessing

# %%
data=pd.read_csv(data_file)
print(data.columns)
# Out:
# Index(['data_somministrazione', 'area', 'totale', 'sesso_maschile',
#        'sesso_femminile', 'prima_dose', 'seconda_dose', 'pregressa_infezione',
#        'codice_NUTS1', 'codice_NUTS2', 'codice_regione_ISTAT', 'nome_area'],
#       dtype='object')

# %%
data.head(5)
# Out:
#   data_somministrazione area  totale  sesso_maschile  sesso_femminile  \
# 0            2021-03-08  VDA     488             233              255
# 1            2021-04-23  UMB    6656            2820             3836
# 2            2021-08-12  VDA     375             204              171
# 3            2021-08-27  TOS   15905            8416             7489
# 4            2021-05-12  EMR   38957           18308            20649
#
#    prima_dose  seconda_dose  pregressa_infezione codice_NUTS1 codice_NUTS2  \
# 0         240           245                    3          ITC         ITC2
# 1        3299          3158                  199          ITI         ITI2
# 2         117           248                   10          ITC         ITC2
# 3        7416          7965                  524          ITI         ITI1
# 4       28468          9697                  792          ITH         ITH5
#
#    codice_regione_ISTAT                       nome_area
# 0                     2  Valle d'Aosta / Vallée d'Aoste
# 1                    10                          Umbria
# 2                     2  Valle d'Aosta / Vallée d'Aoste
# 3                     9                         Toscana
# 4                     8                  Emilia-Romagna

# %% [markdown]
# ### Popolazione

# %%
np.unique(data['area'])
# Out:
# array(['ABR', 'BAS', 'CAL', 'CAM', 'EMR', 'FVG', 'LAZ', 'LIG', 'LOM',
#        'MAR', 'MOL', 'PAB', 'PAT', 'PIE', 'PUG', 'SAR', 'SIC', 'TOS',
#        'UMB', 'VDA', 'VEN'], dtype=object)

# %%
  
popolazione={'ABR': 1293941,
            'BAS': 553254,
            'CAL': 1894110,
            'CAM': 5712143,
            'EMR': 4464119,
            'FVG': 1206216,
            'LAZ': 5755700,
            'LIG': 1524826,
            'LOM': 10027602,
            'MAR': 1512672,
            'MOL': 300516,
            'PIE': 4311217,
            'PUG': 3953305,
            'SAR': 1611621,
            'SIC': 4875290,
            'TOS': 3692555,
            'UMB': 870165,
            'VDA': 125034,
            'VEN': 4879133,
            'PAT': 545425,
            'PAB': 532644}

# %% [markdown]
# ## Somministrazioni per regione

# %%
regione='TOS'
variabili=['totale','prima_dose','seconda_dose']


sub_df=data[data['area']==regione]
sub_df.sort_values(by='data_somministrazione',inplace=True)

fig=go.Figure()
    
    
for v in variabili:
    fig.add_trace(go.Scatter(x=sub_df['data_somministrazione'],
                             y=moving_function_rev1(sub_df[v],np.mean,3,3),
                             mode='lines',
                            name=v))
   
fig.update_layout(
    title='Somministrazioni %s'%regione,
    autosize=False,
    showlegend=True,
    width=900,
    height=600)
fig.show()

# %%
ita_df=data.groupby('data_somministrazione').sum()
ita_df.reset_index(inplace=True)
ita_df.tail(10)
# Out:
#     data_somministrazione  totale  sesso_maschile  sesso_femminile  \
# 237            2021-08-21  155402           85343            70059
# 238            2021-08-22  112521           61930            50591
# 239            2021-08-23  308532          162820           145712
# 240            2021-08-24  278762          147028           131734
# 241            2021-08-25  291592          153988           137604
# 242            2021-08-26  279342          146810           132532
# 243            2021-08-27  286689          151917           134772
# 244            2021-08-28  224692          121895           102797
# 245            2021-08-29  158371           84906            73465
# 246            2021-08-30  141431           72880            68551
#
#      prima_dose  seconda_dose  pregressa_infezione  codice_regione_ISTAT
# 237       74572         76131                 4699                   214
# 238       46501         63329                 2691                   214
# 239      137499        159935                11098                   214
# 240      126337        141805                10620                   214
# 241      120356        161163                10073                   214
# 242      111814        157914                 9614                   214
# 243      106123        171633                 8933                   214
# 244       87890        129649                 7153                   214
# 245       62021         91555                 4795                   214
# 246       56042         80023                 5366                   200

# %%
variabili=['totale','prima_dose','seconda_dose']

fig=go.Figure()
    
    
for v in variabili:
    fig.add_trace(go.Scatter(x=ita_df['data_somministrazione'],
                             y=moving_function_rev1(ita_df[v],np.mean,3,3),
                             mode='lines',
                            name=v))
   
fig.update_layout(
    title='Somministrazioni Italia',
    autosize=False,
    showlegend=True,
    width=900,
    height=600)
fig.show()

# %% [markdown]
# ## Ciclo completo in rapporto alla popolazione

# %%
data_regionali_cumulativi=data.groupby('area').sum()
data_regionali_cumulativi
# Out:
#         totale  sesso_maschile  sesso_femminile  prima_dose  seconda_dose  \
# area
# ABR    1734129          833327           900802      911651        796608
# BAS     717702          344777           372925      391983        318718
# CAL    2263274         1091496          1171778     1207960       1043364
# CAM    7206671         3474316          3732355     3768218       3324180
# EMR    5823660         2794659          3029001     3134371       2588147
# FVG    1514481          729089           785392      789676        691643
# LAZ    7762923         3677855          4085068     4116927       3549800
# LIG    1984140          939899          1044241     1060015        911883
# LOM   13641083         6587367          7053716     7220218       6188699
# MAR    1942756          932610          1010146     1018565        889622
# MOL     408867          196024           212843      215907        188011
# PAB     615345          305594           309751      323854        279721
# PAT     695878          339792           356086      361770        312268
# PIE    5480920         2620506          2860414     2921015       2463901
# PUG    5348492         2538613          2809879     2855245       2406034
# SAR    2110139         1007781          1102358     1147312        942737
# SIC    5691376         2717534          2973842     3063344       2572163
# TOS    4829170         2298367          2530803     2657746       2106449
# UMB    1161842          550165           611677      624456        520633
# VDA     154791           75421            79370       81521         70809
# VEN    6235499         3022291          3213208     3317417       2777074
#
#       pregressa_infezione  codice_regione_ISTAT
# area
# ABR                 25870                  3120
# BAS                  7001                  4114
# CAL                 11950                  4374
# CAM                114273                  3660
# EMR                101142                  1944
# FVG                 33162                  1458
# LAZ                 96196                  2964
# LIG                 12242                  1729
# LOM                232166                   741
# MAR                 34569                  2684
# MOL                  4949                  3290
# PAB                 11770                   964
# PAT                 21840                   964
# PIE                 96004                   246
# PUG                 87213                  3920
# SAR                 20090                  4920
# SIC                 55869                  4693
# TOS                 64975                  2205
# UMB                 16753                  2410
# VDA                  2461                   478
# VEN                141008                  1225

# %%
rate_seconda_dose={}
rate_prima_dose={}
for reg in np.unique(data['area']):
    rate_seconda_dose[reg]=100*data_regionali_cumulativi.loc[reg]['seconda_dose']/popolazione[reg]
    rate_prima_dose[reg]=100*data_regionali_cumulativi.loc[reg]['prima_dose']/popolazione[reg]

for r in rate_prima_dose.keys():
    print('%s  Prima dose: %4.2f   Seconda dose: %4.2f'%(r,rate_prima_dose[r],rate_seconda_dose[r]))
# Out:
# ABR  Prima dose: 70.46   Seconda dose: 61.56
# BAS  Prima dose: 70.85   Seconda dose: 57.61
# CAL  Prima dose: 63.77   Seconda dose: 55.08
# CAM  Prima dose: 65.97   Seconda dose: 58.19
# EMR  Prima dose: 70.21   Seconda dose: 57.98
# FVG  Prima dose: 65.47   Seconda dose: 57.34
# LAZ  Prima dose: 71.53   Seconda dose: 61.67
# LIG  Prima dose: 69.52   Seconda dose: 59.80
# LOM  Prima dose: 72.00   Seconda dose: 61.72
# MAR  Prima dose: 67.34   Seconda dose: 58.81
# MOL  Prima dose: 71.85   Seconda dose: 62.56
# PAB  Prima dose: 60.80   Seconda dose: 52.52
# PAT  Prima dose: 66.33   Seconda dose: 57.25
# PIE  Prima dose: 67.75   Seconda dose: 57.15
# PUG  Prima dose: 72.22   Seconda dose: 60.86
# SAR  Prima dose: 71.19   Seconda dose: 58.50
# SIC  Prima dose: 62.83   Seconda dose: 52.76
# TOS  Prima dose: 71.98   Seconda dose: 57.05
# UMB  Prima dose: 71.76   Seconda dose: 59.83
# VDA  Prima dose: 65.20   Seconda dose: 56.63
# VEN  Prima dose: 67.99   Seconda dose: 56.92

# %%
fig=go.Figure()


ordine=np.argsort(list(rate_seconda_dose.values()))

fig.add_trace(go.Bar(x=np.array(list(rate_seconda_dose.keys()))[ordine],
                     y=np.array(list(rate_seconda_dose.values()))[ordine],
                     name='Seconda dose'))

fig.add_trace(go.Bar(x=np.array(list(rate_prima_dose.keys()))[ordine],
                     y=np.array(list(rate_prima_dose.values()))[ordine],
                     name='Prima dose'))

fig.update_layout(
    title='Percentuale vaccinati ciclo completo',
    autosize=False,
    showlegend=True,
    width=1200,
    height=400)

# %%
fig=go.Figure()

ordine=np.argsort(list(rate_prima_dose.values()))

fig.add_trace(go.Bar(x=np.array(list(rate_prima_dose.keys()))[ordine],
                     y=np.array(list(rate_prima_dose.values()))[ordine]))

fig.update_layout(
    title='Percentuale vaccinati prima dose',
    autosize=False,
    showlegend=False,
    width=1200,
    height=400)
