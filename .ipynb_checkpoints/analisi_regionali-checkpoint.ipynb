# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

from aidam.variables_selection import find_non_redundant_subset

# %% [markdown]
# ## Parametri

# %%
data_file='dpc-covid19-ita-regioni-latest.csv'

# %% [markdown]
# ## Lettura dati e preprocessing

# %%
data=pd.read_csv(data_file)

print('Dimensione dati:',data.shape)


selected_columns=['ricoverati_con_sintomi', 'terapia_intensiva',
       'totale_ospedalizzati', 'isolamento_domiciliare',
       'totale_attualmente_positivi','dimessi_guariti',
                  'deceduti', 'totale_casi', 'tamponi']

print('%d selected columns'%len(selected_columns))

data.iloc[:,3:]
# Out:
# Dimensione dati: (21, 18)
# 9 selected columns
#     denominazione_regione        lat       long  ricoverati_con_sintomi  \
# 0                 Abruzzo  42.351222  13.398438                     280
# 1              Basilicata  40.639471  15.805148                      22
# 2            P.A. Bolzano  46.499335  11.356624                     223
# 3                Calabria  38.905976  16.594402                     101
# 4                Campania  40.839566  14.250850                     448
# 5          Emilia Romagna  44.494367  11.341721                    3354
# 6   Friuli Venezia Giulia  45.649435  13.768136                     212
# 7                   Lazio  41.892770  12.483667                     878
# 8                 Liguria  44.411493   8.932699                     998
# 9               Lombardia  45.466794   9.190347                   10681
# 10                 Marche  43.616760  13.518875                     977
# 11                 Molise  41.557748  14.659161                      27
# 12               Piemonte  45.073274   7.680687                    2633
# 13                 Puglia  41.125596  16.867367                     480
# 14               Sardegna  39.215312   9.110616                      92
# 15                Sicilia  38.115697  13.362357                     346
# 16                Toscana  43.769231  11.255889                    1037
# 17            P.A. Trento  46.068935  11.121231                     300
# 18                 Umbria  43.106758  12.388247                     144
# 19          Valle d'Aosta  45.737503   7.320149                      73
# 20                 Veneto  45.434905  12.338452                    1447
#
#     terapia_intensiva  totale_ospedalizzati  isolamento_domiciliare  \
# 0                  64                   344                     516
# 1                  16                    38                      95
# 2                  43                   266                     525
# 3                  23                   124                     248
# 4                 114                   562                     607
# 5                 301                  3655                    5195
# 6                  54                   266                     688
# 7                 113                   991                     844
# 8                 154                  1152                     875
# 9                1263                 11944                   10245
# 10                166                  1143                    1652
# 11                  8                    35                      46
# 12                408                  3041                    2909
# 13                 76                   556                     539
# 14                 20                   112                     350
# 15                 68                   414                     681
# 16                259                  1296                    1677
# 17                 66                   366                     728
# 18                 46                   190                     580
# 19                 24                    97                     281
# 20                326                  1773                    4367
#
#     totale_attualmente_positivi  nuovi_attualmente_positivi  dimessi_guariti  \
# 0                           860                         122               23
# 1                           133                          21                0
# 2                           791                          43               67
# 3                           372                          39                7
# 4                          1169                          97               58
# 5                          8850                         594              792
# 6                           954                          43              197
# 7                          1835                         160              155
# 8                          2027                         201              260
# 9                         22189                        1598             7839
# 10                         2795                         156                9
# 11                           81                          28               14
# 12                         5950                         394              135
# 13                         1095                          72               22
# 14                          462                          50               13
# 15                         1095                         159               36
# 16                         2973                         197               95
# 17                         1094                          36              117
# 18                          770                          84               12
# 19                          378                           3                2
# 20                         6140                         395              508
#
#     deceduti  totale_casi  tamponi  note_it  note_en
# 0         63          946     5488      NaN      NaN
# 1          1          134     1046      NaN      NaN
# 2         48          906     7744      NaN      NaN
# 3         14          393     5933      NaN      NaN
# 4         83         1310     8346      NaN      NaN
# 5       1174        10816    42395      NaN      NaN
# 6         72         1223    10721      NaN      NaN
# 7        106         2096    22771      NaN      NaN
# 8        280         2567     7304      NaN      NaN
# 9       4861        34889    87713      NaN      NaN
# 10       310         3114     8623      NaN      NaN
# 11         8          103      670      NaN      NaN
# 12       449         6534    18054      NaN      NaN
# 13        65         1182     9191      NaN      NaN
# 14        19          494     3461      NaN      NaN
# 15        33         1164     9658      NaN      NaN
# 16       158         3226    20952      NaN      NaN
# 17        86         1297     4600      NaN      NaN
# 18        20          802     5428      NaN      NaN
# 19        28          408     1203      NaN      NaN
# 20       287         6935    79759      NaN      NaN

# %% [markdown]
# ### Analisi di ridondanza
#
# Basata su correlazione lineare fra le variabili

# %%
sub_data=data[selected_columns]

uncorrelated_subset,is_correlate= find_non_redundant_subset(sub_data.values,correlation_threshold=0.95,
                                                            pvalue_threshold=0.02,
                                                            iterations=None,
                                                            verbose=True)
# Out:
# [1/9] 3 vertex in dominating set
# [2/9] 4 vertex in dominating set
# [3/9] 4 vertex in dominating set
# [4/9] 3 vertex in dominating set
# [5/9] 4 vertex in dominating set
# [6/9] 4 vertex in dominating set
# [7/9] 4 vertex in dominating set
# [8/9] 4 vertex in dominating set
# [9/9] 4 vertex in dominating set
# array([[ True,  True,  True, False,  True, False, False,  True, False],
#        [ True,  True,  True, False,  True, False,  True,  True, False],
#        [ True,  True,  True, False,  True, False,  True,  True, False],
#        [False, False, False,  True,  True, False,  True,  True, False],
#        [ True,  True,  True,  True,  True, False,  True,  True, False],
#        [False, False, False, False, False,  True, False, False, False],
#        [False,  True,  True,  True,  True, False,  True,  True, False],
#        [ True,  True,  True,  True,  True, False,  True,  True, False],
#        [False, False, False, False, False, False, False, False,  True]])

# %%
representative_vars=[selected_columns[i] for i in uncorrelated_subset]
representative_vars
# Out:
# [[ True  True  True False  True False False  True False]
#  [ True  True  True False  True False  True  True False]
#  [ True  True  True False  True False  True  True False]
#  [False False False  True  True False  True  True False]
#  [ True  True  True  True  True False  True  True False]
#  [False False False False False  True False False False]
#  [False  True  True  True  True False  True  True False]
#  [ True  True  True  True  True False  True  True False]
#  [False False False False False False False False  True]]

# %% [markdown]
# ## Grafici
#
# ### Grafico a barre

# %%
x_pos = np.arange(data.shape[0])


for varname in representative_vars:
    plt.bar(x_pos, data[varname], align='center')
    plt.xticks(x_pos, data['denominazione_regione'],rotation=90)
    plt.ylabel(varname)
    plt.xlabel('Regione')
    plt.show()



media_tamponi_per_positivo=np.nanmean(data['tamponi']/data['totale_attualmente_positivi'])
print(media_tamponi_per_positivo)
plt.bar(x_pos, data['tamponi']/data['totale_attualmente_positivi'], align='center')
plt.xticks(x_pos, data['denominazione_regione'],rotation=90)
plt.ylabel('Tamponi')
plt.xlabel('Regione')
plt.title('Tamponi effettuati per ogni positivo')
plt.hlines(media_tamponi_per_positivo,xmin=0,xmax=20,colors='r',linestyles='dashed',label='End fit')
plt.show()
# Out:
# "\nmedia_tamponi_per_positivo=np.nanmean(data['tamponi']/data['totale_attualmente_positivi'])\nprint(media_tamponi_per_positivo)\nplt.bar(x_pos, data['tamponi']/data['totale_attualmente_positivi'], align='center')\nplt.xticks(x_pos, data['denominazione_regione'],rotation=90)\nplt.ylabel('Tamponi')\nplt.xlabel('Regione')\nplt.title('Tamponi effettuati per ogni positivo')\nplt.hlines(media_tamponi_per_positivo,xmin=0,xmax=20,colors='r',linestyles='dashed',label='End fit')\nplt.show()\n"

# %% [markdown]
# ## Relazione fra le varie misure

# %%
fig,ax=plt.subplots(len(selected_columns),len(selected_columns),figsize=(15,15))


for r,cx in enumerate(selected_columns):
    for c,cy in enumerate(selected_columns):
        if c>r:
            ax[r,c].plot(data[cx],data[cy],'b.')

# %%
len(ax)
# Out:
# 9
